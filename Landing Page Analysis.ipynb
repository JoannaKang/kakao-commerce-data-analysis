# %%
import pandas as pd
import numpy as np

# %%
landingpage = pd.read_excel("C:\\Users\Joanna Kang\\Desktop\TASK\\5. Data Anaylsis\\6월 페이지 랜딩 분석\\Analytics All Web Site Data All Traffic 20200601-20200629.xlsx", sheet_name
                        = "Dataset1")

# %%
landingpage
# Out:
#          Source/Medium                                       Landing Page  \
# 0    Facebook / Social  /products/happy-weeks-zipper-file-folder-ryan?...
# 1    Facebook / Social  /products/baby-dreaming-theme-iphone-case-x-xs...
# 2    Facebook / Social  /collections/all-plush-toys/products/lemon-ter...
# 3    Facebook / Social                            /collections/sale-store
# 4    Facebook / Social  /products/baby-dreaming-theme-compact-glitter-...
# ..                 ...                                                ...
# 258  Facebook / Social  /products/yumyum-friends-mini-bag-little-apeac...
# 259  Facebook / Social  /products/yumyum-friends-mini-tote-bag-little-...
# 260  Facebook / Social                                     /search?q=Lamp
# 261  Facebook / Social                                 /search?q=Tote+bag
# 262                NaN                                                NaN
#
#      Users  New Users  Sessions  Bounce Rate  Pages/Session  \
# 0        1          0         1     0.000000     102.000000
# 1        1          0         1     0.000000      30.000000
# 2        1          0         1     0.000000      16.000000
# 3        1          0         1     0.000000      28.000000
# 4        1          1         1     0.000000      16.000000
# ..     ...        ...       ...          ...            ...
# 258      3          1         3     1.000000       1.000000
# 259      4          0         4     1.000000       1.000000
# 260      1          0         1     1.000000       1.000000
# 261      1          0         1     1.000000       1.000000
# 262   1226        596      1305     0.595402       2.778544
#
#      Avg. Session Duration  E-commerce Conversion Rate  Transactions  Revenue
# 0               6470.00000                    0.000000             0     0.00
# 1               2664.00000                    1.000000             1    43.97
# 2               2092.00000                    0.000000             0     0.00
# 3               1437.00000                    0.000000             0     0.00
# 4                899.00000                    0.000000             0     0.00
# ..                     ...                         ...           ...      ...
# 258                0.00000                    0.000000             0     0.00
# 259                0.00000                    0.000000             0     0.00
# 260                0.00000                    0.000000             0     0.00
# 261                0.00000                    0.000000             0     0.00
# 262               98.70728                    0.002299             3   149.93
#
# [263 rows x 11 columns]
